# %%
# pip install matplotlib seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 讀取資料集
data = pd.read_csv('Data/recorded_data-3.txt', sep='\t')

data['time'] = pd.to_datetime(data['time'])
data['time'] = data['time'].dt.strftime('%H:%M:%S')
data_subset = data.iloc[100:]
data_subset.info()
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 100 to 206
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   time        107 non-null    object
#  1   position_x  107 non-null    float64
#  2   position_y  107 non-null    float64
#  3   scroll_x    107 non-null    float64
#  4   scroll_y    107 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 4.3+ KB
#        time  position_x  position_y    scroll_x    scroll_y
# 0  10:22:35  498.794264  499.435179  498.794264  499.435179
# 1  10:22:35  502.409397  507.869991  502.409397  507.869991
# 2  10:22:35  526.941834  513.626619  526.941834  513.626619
# 3  10:22:36  531.906218  506.219713  531.906218  506.219713
# 4  10:22:36  537.702199  456.141998  537.702199  456.141998

# %%
# 創建 2D 密度圖
sns.kdeplot(x=data_subset['position_x'], y=data_subset['position_y'], cmap="Oranges", fill=True, thresh=0)

# 加入軸標籤和標題
plt.xlabel('Position X')
plt.ylabel('Position Y')
plt.title('Heatmap of Screen Positions')

plt.gca().invert_yaxis()
# 顯示熱力圖
plt.show()

# %%
sns.set_theme(style="whitegrid")

# 創建邊線柱狀圖
sns.histplot(data_subset, x='position_x', y='position_y', cbar=True, cmap="Blues", cbar_kws={'label': 'Density'})

# 加入軸標籤和標題
plt.xlabel('Position X')
plt.ylabel('Position Y')
plt.title('Heatmap of Screen Positions')
plt.gca().invert_yaxis()
# 顯示圖形
plt.show()
